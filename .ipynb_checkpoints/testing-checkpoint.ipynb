# %%
import numpy as np
import pandas as pd
import pickle

# %%
model = pickle.load(open('model.pkl', 'rb'))

# %%
df = pd.read_csv('./data/cleaned_wine.csv')

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  residual sugar  chlorides  \
# 0            7.4              0.70             1.9      0.076
# 1            7.8              0.88             2.6      0.098
# 2            7.8              0.76             2.3      0.092
# 3           11.2              0.28             1.9      0.075
# 4            7.4              0.70             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates wine
# 0                 11.0                  34.0   0.9978  3.51       0.56  red
# 1                 25.0                  67.0   0.9968  3.20       0.68  red
# 2                 15.0                  54.0   0.9970  3.26       0.65  red
# 3                 17.0                  60.0   0.9980  3.16       0.58  red
# 4                 11.0                  34.0   0.9978  3.51       0.56  red

# %%
input_array = np.array([7.4, 0.7, 1.9, 0.076, 11.0, 34.0, 0.9978, 3.51, 0.56])

# %%
input_array = input_array.reshape(1, -1)

# %%
cols = list(df.columns)

# %%
cols.remove('wine')

# %%
cols
# Out:
# ['fixed acidity',
#  'volatile acidity',
#  'residual sugar',
#  'chlorides',
#  'free sulfur dioxide',
#  'total sulfur dioxide',
#  'density',
#  'pH',
#  'sulphates']

# %%
wine1 = pd.DataFrame(columns=cols, data=input_array)

# %%
wine1
# Out:
#    fixed acidity  volatile acidity  residual sugar  chlorides  \
# 0            7.4               0.7             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates
# 0                 11.0                  34.0   0.9978  3.51       0.56

# %%
model.predict(wine1)
# Out:
# array(['red'], dtype=object)
